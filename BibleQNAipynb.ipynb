# %%
Train=[{
    "data": [
        {
            "title": "Genesis 1:1",
            "paragraphs": [
                {
                    "context": "In the beginning God created the heavens and the earth.",
                    "qas": [
                        {
                            "question": "What did God create in the beginning?",
                            "id": "1",
                            "answers": [
                                {
                                    "text": "the heavens and the earth",
                                    "answer_start": 19
                                }
                            ]
                        }
                    ]
                }
            ]
        },
        {
            "title": "Genesis 1:2",
            "paragraphs": [
                {
                    "context": "Now the earth was formless and empty, darkness was over the surface of the deep, and the Spirit of God was hovering over the waters.",
                    "qas": [
                        {
                            "question": "What was the state of the earth in the beginning?",
                            "id": "2",
                            "answers": [
                                {
                                    "text": "formless and empty",
                                    "answer_start": 8
                                }
                            ]
                        },
                        {
                            "question": "What was hovering over the waters?",
                            "id": "3",
                            "answers": [
                                {
                                    "text": "the Spirit of God",
                                    "answer_start": 82
                                }
                            ]
                        }
                    ]
                }
            ]
        },
        {
            "title": "Genesis 1:3",
            "paragraphs": [
                {
                    "context": "And God said, 'Let there be light,' and there was light.",
                    "qas": [
                        {
                            "question": "What did God say?",
                            "id": "4",
                            "answers": [
                                {
                                    "text": "'Let there be light,'",
                                    "answer_start": 9
                                }
                            ]
                        },
                        {
                            "question": "What happened when God spoke?",
                            "id": "5",
                            "answers": [
                                {
                                    "text": "there was light",
                                    "answer_start": 33
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ]
}]

# %%
import json

# Create a list to add to the JSON file


# Open the file in write mode
with open("Train.json", "w") as f:
    # Write the list to the file
    json.dump(Data, f)

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 64.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 81.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 87.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 15.4 MB/s eta 0:00:00
# ...

# %%
Test=[{
            "title": "Genesis 1:4",
            "paragraphs": [
                {
                    "context": "God saw that the light was good, and he separated the light from the darkness.",
                    "qas": [
                        {
                            "question": "What did God see about the light?",
                            "id": "6",
                            "answers": [
                                {
                                    "text": "that it was good",
                                    "answer_start": 16
                                }
                            ]
                        },
                        {
                            "question": "What did God do with the light?",
                            "id": "7",
                            "answers": [
                                {
                                    "text": "he separated it from the darkness",
                                    "answer_start": 44
                                }
                            ]
                        }
                    ]
                }
            ]
        },
        {
            "title": "Genesis 1:5",
            "paragraphs": [
                {
                    "context": "God called the light 'day,' and the darkness he called 'night.' And there was evening, and there was morning - the first day.",
                    "qas": [
                        {
                            "question": "What did God call the light?",
                            "id": "8",
                            "answers": [
                                {
                                    "text": "'day,'",
                                    "answer_start": 14
                                }
                            ]
                        },
                        {
                            "question": "What did God call the darkness?",
                            "id": "9",
                            "answers": [
                                {
                                                                    "text": "'night.'",
                                "answer_start": 44
                            }
                        ]
                    },
                    {
                        "question": "What was the first day?",
                        "id": "10",
                        "answers": [
                            {
                                "text": "the evening and the morning",
                                "answer_start": 77
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:6",
        "paragraphs": [
            {
                "context": "And God said, 'Let there be a vault between the waters to separate water from water.'",
                "qas": [
                    {
                        "question": "What did God want to separate with the vault?",
                        "id": "11",
                        "answers": [
                            {
                                "text": "water from water",
                                "answer_start": 50
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:7",
        "paragraphs": [
            {
                "context": "So God made the vault and separated the water under the vault from the water above it. And it was so.",
                "qas": [
                    {
                        "question": "What did God make?",
                        "id": "12",
                        "answers": [
                            {
                                "text": "the vault",
                                "answer_start": 3
                            }
                        ]
                    },
                    {
                        "question": "What did the vault separate?",
                        "id": "13",
                        "answers": [
                            {
                                "text": "the water under it from the water above it",
                                "answer_start": 53
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:8",
        "paragraphs": [
            {
                "context": "God called the vault 'sky.' And there was evening, and there was morning - the second day.",
                "qas": [
                    {
                        "question": "What did God call the vault?",
                        "id": "14",
                        "answers": [
                            {
                                "text": "'sky.'",
                                "answer_start": 16
                            }
                        ]
                    },
                    {
                        "question": "What was the second day?",
                        "id": "15",
                        "answers": [
                            {
                                "text": "the evening and the morning",
                                "answer_start": 48
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:9",
        "paragraphs": [
            {
                "context": "And God said, 'Let the water under the sky be gathered to one place, and let dry ground appear.' And it was so.",
                "qas": [
                    {
                        "question": "What did God want to appear?",
                        "id": "16",
                        "answers": [
                            {
                                "text": "dry ground",
                                "answer_start": 64
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:10",
        "paragraphs": [
            {
                "context": "God called the dry ground 'land,' and the gathered waters he called 'seas.' And God saw that it was good.",
                "qas": [
                    {
                        "question": "What did God call the dry ground?",
                        "id": "17",
                        "answers": [
                            {
                                "text": "'land,'",
                                "answer_start": 16
                            }
                        ]
                    },
                    {
                        "question": "What did God call the gathered waters?",
                        "id": "18",
                        "answers": [
                            {
                                "text": "'seas.'",
                                "answer_start": 45
                            }
                        ]
                    },
                    {
                        "question": "What did God see after he named the land and seas?",
                        "id": "19",
                        "answers": [
                            {
                                "text": "that it was good",
                                "answer_start": 68
                            }
                        ]
                    }
                ]
            }
        ]
    }
                    
                                    ]

# %%
with open("Test.json", "w") as f:
    # Write the list to the file
    json.dump(Test_Data, f)

# %%
Preds=[{
        "title": "Genesis 1:14",
        "paragraphs": [
            {
                "context": "And God said, 'Let there be lights in the vault of the sky to separate the day from the night, and let them serve as signs to mark sacred times, and days and years,",
                "qas": [
                                        {
                        "question": "What did God create to separate the day from the night?",
                        "id": "26",
                        "answers": [
                            {
                                "text": "lights in the vault of the sky",
                                "answer_start": 13
                            }
                        ]
                    },
                    {
                        "question": "What were the lights in the vault of the sky supposed to serve as?",
                        "id": "27",
                        "answers": [
                            {
                                "text": "signs to mark sacred times, and days and years",
                                "answer_start": 81
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:15",
        "paragraphs": [
            {
                "context": "and let them be lights in the vault of the sky to give light on the earth.' And it was so.",
                "qas": [
                    {
                        "question": "What did God want the lights in the sky to do?",
                        "id": "28",
                        "answers": [
                            {
                                "text": "give light on the earth",
                                "answer_start": 52
                            }
                        ]
                    },
                    {
                        "question": "Did what God commanded happen?",
                        "id": "29",
                        "answers": [
                            {
                                "text": "yes",
                                "answer_start": 71
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:16",
        "paragraphs": [
            {
                "context": "God made two great lights - the greater light to govern the day and the lesser light to govern the night. He also made the stars.",
                "qas": [
                    {
                        "question": "How many great lights did God make?",
                        "id": "30",
                        "answers": [
                            {
                                "text": "two",
                                "answer_start": 9
                            }
                        ]
                    },
                    {
                        "question": "What was the greater light for?",
                        "id": "31",
                        "answers": [
                            {
                                "text": "to govern the day",
                                "answer_start": 39
                            }
                        ]
                    },
                    {
                        "question": "What was the lesser light for?",
                        "id": "32",
                        "answers": [
                            {
                                "text": "to govern the night",
                                "answer_start": 61
                            }
                        ]
                    },
                    {
                        "question": "What else did God make?",
                        "id": "33",
                        "answers": [
                            {
                                "text": "the stars",
                                "answer_start": 76
                            }
                        ]
                    }
                ]
            }
        ]
    },
    {
        "title": "Genesis 1:17",
        "paragraphs": [
            {
                "context": "God set them in the vault of the sky to give light on the earth,",
                "qas": [
                    {
                        "question": "Where did God set the lights?",
                        "id": "34",
                        "answers": [
                            {
                                "text": "in the vault of the sky",
                                "answer_start": 18
                            }
                        ]
                    },
                    {
                        "question": "What was the purpose of setting the lights in the vault of the sky?",
                        "id": "35",
                        "answers": [
                            {
                                "text": "to give light on the earth",
                                "answer_start": 44
                            }
                        ]
                    }
                ]
            }
        ]
    }

                ]

# %%
with open("Preds.json", "w") as f:
    # Write the list to the file
    json.dump(Preds, f)

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
model_type="bert"
model_name= "bert-base-cased"
if model_type == "bert":
    model_name = "bert-base-cased"

elif model_type == "roberta":
    model_name = "roberta-base"

elif model_type == "distilbert":
    model_name = "distilbert-base-cased"

elif model_type == "distilroberta":
    model_type = "roberta"
    model_name = "distilroberta-base"

elif model_type == "electra-base":
    model_type = "electra"
    model_name = "google/electra-base-discriminator"

elif model_type == "electra-small":
    model_type = "electra"
    model_name = "google/electra-small-discriminator"

elif model_type == "xlnet":
    model_name = "xlnet-base-cased"

# %%
# Configure the model 
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 16
model_args.evaluate_during_training = True
model_args.n_best_size=3
model_args.num_train_epochs=5

# %%
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 5,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %%
model = QuestionAnsweringModel(
    model_type,model_name, args=train_args,use_cuda= False
)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(Train, eval_data=Test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-66c05365c839> in <module>
# ----> 1 model.train_model(Train, eval_data=Test)
#
# /usr/local/lib/python3.8/dist-packages/simpletransformers/question_answering/question_answering_model.py in train_model(self, train_data, output_dir, show_running_loss, args, eval_data, verbose, **kwargs)
#     447                 train_examples = train_data
#     448
# --> 449             train_dataset = self.load_and_cache_examples(train_examples)
#     450
#     451         os.makedirs(output_dir, exist_ok=True)
#
# /usr/local/lib/python3.8/dist-packages/simpletransformers/question_answering/question_answering_model.py in load_and_cache_examples(self, examples, evaluate, no_cache, output_examples)
#     287             os.makedirs(self.args.cache_dir, exist_ok=True)
#     288
# ...
